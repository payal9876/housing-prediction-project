# %%
from housing.config.configuration import Configuration

# %%
from housing.constant import CURRENT_TIME_STAMP

# %%
CURRENT_TIME_STAMP
# Out:
# '2022-07-16-11-38-35'

# %%
from housing.constant import CONFIG_FILE_PATH

# %%
CONFIG_FILE_PATH
# Out:
# 'c:\\Users\\payal\\housing-prediction-project\\config\\config.yaml'

# %%
import os

# %%
os.chdir("c:\\Users\\payal\\housing-prediction-project")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\payal\\housing-prediction-project'

# %%
from housing.config.configuration import Configuration

# %%
con=Configuration()

# %%
con.get_training_pipeline_config()
# Out:
# TrainingPipelineConfig(artifact_dir='c:\\Users\\payal\\housing-prediction-project\\housing\\artifact')

# %%
con.get_data_ingestion_config()
# Out:
# DataIngestionConfig(dataset_download_url='https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz', tgz_download_dir='c:\\Users\\payal\\housing-prediction-project\\housing\\artifact\\data_ingestion\\2022-07-16-12-00-59\\tgz_data', raw_data_dir='c:\\Users\\payal\\housing-prediction-project\\housing\\artifact\\data_ingestion\\2022-07-16-12-00-59\\raw_data', ingested_train_dir='c:\\Users\\payal\\housing-prediction-project\\housing\\artifact\\data_ingestion\\2022-07-16-12-00-59\\ingested_data\\train', ingested_test_dir='c:\\Users\\payal\\housing-prediction-project\\housing\\artifact\\data_ingestion\\2022-07-16-12-00-59\\ingested_data\\test')

# %%
from six.moves import urllib

# %%
urllib.request.urlopen("https://www.facebook.com/")

# %%
import pandas as pd

# %%
train_file_path= r'C:\Users\payal\housing-prediction-project\housing\artifact\data_ingestion\2022-07-16-17-11-46\ingested_data\train\housing.csv'

# %%
df=pd.read_csv(r"C:\Users\payal\housing-prediction-project\housing\artifact\data_ingestion\2022-07-16-17-11-46\ingested_data\train\housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -121.46     38.52                29.0       3873.0           797.0
# 1        -117.23     33.09                 7.0       5320.0           855.0
# 2        -119.04     35.37                44.0       1618.0           310.0
# 3        -117.13     32.75                24.0       1877.0           519.0
# 4        -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 16507    -117.07     33.03                14.0       6665.0          1231.0
# 16508    -121.42     38.51                15.0       7901.0          1422.0
# 16509    -122.72     38.44                48.0        707.0           166.0
# 16510    -122.70     38.31                14.0       3155.0           580.0
# 16511    -122.14     39.97                27.0       1079.0           222.0
#
# ...

# %%
from housing .entity import artifact_entity

# %%
object=artifact_entity.DataIngestionArtifact()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7068\3127206589.py in <module>
# ----> 1 object=artifact_entity.DataIngestionArtifact()
#       2
#
# TypeError: __new__() missing 4 required positional arguments: 'train_file_path', 'test_file_path', 'is_ingested', and 'message'

# %%
object.train_file_path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7068\2286457186.py in <module>
# ----> 1 object.train_file_path
#
# AttributeError: 'property' object has no attribute 'train_file_path'

# %%
object.fget(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7068\1909111599.py in <module>
# ----> 1 object.fget(j)
#
# NameError: name 'j' is not defined
